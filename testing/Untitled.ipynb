# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
url2="https://marketcheck-prod.apigee.net/v1/search?api_key=6Bb2n9AntX1W2D3QOFtFQhgAcL8tYAxs&seller_type=dealer&state=CA&fuel_type=electric"

# %%
response2=requests.get(url2).json()
pprint(response2)
# Out:
# {'listings': [{'build': {'antibrake_sys': '4-Wheel ABS',
#                          'body_type': 'Hatchback',
#                          'city_miles': '101 miles/gallon',
#                          'doors': 4,
#                          'drivetrain': 'Front Wheel Drive',
#                          'engine': 'ELECTRIC',
#                          'fuel_type': 'Electric',
#                          'highway_miles': '93 miles/gallon',
#                          'made_in': 'United States',
#                          'make': 'Chevrolet',
#                          'model': 'Volt',
#                          'overall_height': '56.60 Inches',
#                          'overall_length': '177.10 Inches',
#                          'overall_width': '70.40 Inches',
#                          'std_seating': '4',
#                          'steering_type': 'R&P',
#                          'tank_size': '9.3 gallon',
#                          'transmission': 'Direct Drive',
# ...

# %%
cars_total=len(response2['listings'][0]['id'])
print(cars_total)
# Out:
# 54

# %%
states=[]
for state in states:
    states.append(response2['listings'][0]['dealer']['state'])
print(states)
# Out:
# []

# %%
states.append(response2['listings'][0]['dealer']['state'])
print(states)
# Out:
# ['PA']
