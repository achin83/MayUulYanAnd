# %%
import json
import requests
import pandas as pd
from pprint import pprint

from config import api_key, client_id

# %%
names=[]
rating=[]
review_count=[]

# %%
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com/v3/businesses/search?&location=CA&locale=en_US&categories=restaurants'


headers = {'Authorization': f"Bearer {api_key}"}

response = requests.get(API_HOST, headers=headers).json()
pprint(response)
# Out:
# {'businesses': [{'alias': 'south-gate-brewing-company-oakhurst-4',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'brewpubs', 'title': 'Brewpubs'}],
#                  'coordinates': {'latitude': 37.3331104,
#                                  'longitude': -119.660292},
#                  'display_phone': '(559) 692-2739',
#                  'distance': 32190.468670098337,
#                  'id': 'hgZUMSrhohHkGKeCEiiy-A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sfwGrEwLisbqugy3X9EBaA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '40233 Enterprise Dr',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Oakhurst',
# ...

# %%
total_rest=len(response['businesses'][0]['id'])
print(total_rest)
# Out:
# 22

# %%
print(response[0]['businesses']['review_count'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-fdac7354448f> in <module>()
# ----> 1 print(response[0]['businesses']['review_count'])
#
# KeyError: 0

# %%
for restaraunt in response['businesses']:
    names.append(response['businesses']['name'])
    rating.append(response['businesses']['rating'])
    review_count.append(response)['businesses']['review_count']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-8877a0f94d78> in <module>()
#       1 for restaraunt in response['businesses']:
# ----> 2     names.append(response['businesses']['name'])
#       3     rating.append(response['businesses']['rating'])
#       4     review_count.append(response)['businesses']['review_count']
#
# TypeError: list indices must be integers or slices, not str

# %%
#dataframe
data=pd.DataFrame({'restaraunts':names,
                  'ratings':rating,
                  'review_count':review_count})
data
# Out:
#                   restaraunts  ratings  \
# 0  South Gate Brewing Company      4.0
# 1  South Gate Brewing Company      4.0
#
#                                         review_count
# 0  {'businesses': [{'id': 'hgZUMSrhohHkGKeCEiiy-A...
# 1  {'businesses': [{'id': 'hgZUMSrhohHkGKeCEiiy-A...

# %%
results=get_business('reviews')
pprint(results)
# Out:
# {'businesses': [],
#  'region': {'center': {'latitude': 37.767413217936834,
#                        'longitude': -122.42820739746094}},
#  'total': 0}

# %%
response=requests.get(url).json()

# %%
pprint(response)
# Out:
# {'error': {'code': 'TOKEN_MISSING',
#            'description': 'An access token must be supplied in order to use '
#                           'this endpoint.'}}
